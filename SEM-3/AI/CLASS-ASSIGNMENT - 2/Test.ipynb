# %%
def fact (n):
  if (n <= 1):
    return 1
  
  return n * fact (n - 1)

print (fact(5))
# Out:
# 120

# %% [markdown]
# Q - 2

# %%
# def define_matrix(m, n):
#   for i in range(0,m):
#     list temp
#     for j in range(0,n):
#       temp[j] = input(f"Enter val at {i}, {j}")
#     matrix[i] = temp

#   return matrix

from typing import List

def define_matrix(m: int, n: int) -> list[list[int]]:
    matrix = []
    for i in range(0, m):
        temp = []
        for j in range(0, n):
            temp.append(int(input(f"Enter val at {i}, {j}")))

        matrix.append(temp)

    return matrix

matrix = define_matrix(2, 2)

def search (matrix: List[List[int]], n: int) -> int:
  count = 0

  for i in range (0, len(matrix)):
      for j in range (0,len(matrix[i])):
          if (matrix[i][j] == n):
              count += 1
  
  return count;

print(matrix)
print(search(matrix,3))
# Out:
# [[1, 2], [3, 4]]
# 1
