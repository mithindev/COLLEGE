# %%
fruits = [
    "Orange",
    "Mango",
    "apple",
    "banana",
    "watermelon",
    "kivi",
    "musk",
    "litchi",
    "tomato",
    "pineapple"
]

for i in range(0, 10, 2):
    print(fruits[i])
# Out:
# Orange
# apple
# watermelon
# musk
# tomato

# %%
fruits = ['Orange', 'Mango', 'apple', 'banana', 'watermelon', 'kivi', 'musk', 'litchi', 'tomato', 'pineapple']

fruits.append(['mithin1', 'mtihin2'])

print(fruits)

for i in fruits:
    if type(i) == str:
        print(i)
    else:
        for x in i:
            print(x)
# Out:
# ['Orange', 'Mango', 'apple', 'banana', 'watermelon', 'kivi', 'musk', 'litchi', 'tomato', 'pineapple', ['mithin1', 'mtihin2']]
# Orange
# Mango
# apple
# banana
# watermelon
# kivi
# musk
# litchi
# tomato
# pineapple
# mithin1
# mtihin2

# %% [markdown]
# # Sort a dictionary w.r.t value

# %%
d = {'1':'a', '2':'b', '3':'c', '4':'d', '5':'e'}

my_list = list(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 d = {'1':'a', '2':'b', '3':'c', '4':'d', '5':'e'}
# ----> 3 my_list = list(d)
#
# TypeError: 'list' object is not callable
