# %% [markdown]
# # CLASS ASSIGNMENT - 05/09/2023

# %% [markdown]
# ### Q - 1

# %%
def sortSentence(sen):
    lst = sen.split('-')

    for i in range(len(lst)):
        for j in range(1, len(lst)):
            if lst[j] < lst[j - 1]:
                lst[j], lst[j - 1] = lst[j - 1], lst[j]

    sorted_sentence = "-".join(lst)

    return sorted_sentence

input_str = "green-red-yellow-black-white"
sorted_str = sortSentence(input_str)
print(sorted_str)
# Out:
# black-green-red-white-yellow

# %% [markdown]
# ### Q - 2
