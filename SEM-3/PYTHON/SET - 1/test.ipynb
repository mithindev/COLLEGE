# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (2, 2))
plt.plot([1, 2, 3, 4])
plt.show()

# %%
a = ('mithin', )
print(type(a))
# Out:
# <class 'tuple'>

# %%
def display(**x):
  for i in x:
    print(i)

display(emp = "mtihin", salary = 10000)
# Out:
# emp
# salary

# %%
t1 = (('a', 23), ('b', 37), ('c', 11), ('d', 29))

t1 = tuple(sorted(list(t1), key = lambda x: x[1]))
print(t1)
# Out:
# (('c', 11), ('a', 23), ('d', 29), ('b', 37))

# %%
import re

print(re.search('\$.+', "jfjvnfjvnfjvnf$1.00"))
# Out:
# <re.Match object; span=(14, 19), match='$1.00'>

# %%
import re

s = "From: dfdfdf.fdfdf.fdf@eeef.com, fdef@frfrf.com, "

print(re.findall(r'From:.+@', s))
# Out:
# ['From: dfdfdf.fdfdf.fdf@eeef.com, fdef@']

# %%
print(len(set(re.findall(r'[^aeiou]','abfeakĬjdknsam'))))
# Out:
# 9

# %%
s = "The parctice of a PINEAPPLE ice cream 20"
# result = re.findall(r"(^[A-Z]+).+(\b\d+)", s)
result = re.findall(r"^[A-Z]+.+\b\d+", s)

print(result)
# Out:
# ['The parctice of a PINEAPPLE ice cream 20']
