# %% [markdown]
# # SET - 1

# %% [markdown]
# Q - 1]

# %%
def countTarget (str, target):
    count = 0

    for ch in str:
        if (ch == target):
            count += 1

    return count

# %% [markdown]
# Q - 2]

# %%
def isPalindrome (str):
    l = len(str)

    for i in range(l//2):
      if (str[i] != str[l - i - 1]):
       return False
    
    return True

# %% [markdown]
# Q - 3]

# %%
def countTarget(str, target):
    count = 0

    for ch in str:
        if ch == target:
            count += 1

    return count

def countVowel(str):
    vowels = {
        'a': 0,
        'e': 0,
        'i': 0,
        'o': 0,
        'u': 0
    }

    for v in vowels:
        vowels[v] = countTarget(str, v)

    print(vowels)

# %% [markdown]
# Q - 4]

# %%
def matchingChar (str1, str2):
    l = len(str1)
    str1 = str1.lower()
    str2 = str2.lower()

    for i in range(l + 1):
        if str1[i] == str2[i]:
            print(f"matching at {i} th locations")

# %% [markdown]
# # SET - 2

# %% [markdown]
# Q - 1]

# %% [markdown]
# Q - 2]

# %%
import array

def removeDuplicates(arr):
    arr.sort()

    temp = array.array('i')
    j = 0
    i = 0

    while i < len(arr) - 1:
        while i < len(arr) - 1 and arr[i] == arr[i + 1]:
            i += 1
        temp.append(arr[i])
        i += 1

    if i < len(arr):
        temp.append(arr[i])

    return temp

# %% [markdown]
# # MATRIX

# %%
row = int(input('Enter the number of rows: '))
col = int(input('Enter the number of columns: '))

matrix = []

for r in range(row):
    row_data = []
    for c in range(col):
        temp = int(input(f"Enter value for row {r + 1}, column {c + 1}: "))
        row_data.append(temp)
    matrix.append(row_data)

print(matrix)
# Out:
#   Cell In[12], line 4
#     matrix = [][]
#                 ^
# SyntaxError: invalid syntax
