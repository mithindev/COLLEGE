# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms
from torch import nn, optim
from torchsummary import summary

print(torch.__version__)

# Transformations to be applied on images
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Defining the training and testing set
trainset = datasets.MNIST('./data', download=True, train=True, transform=transform)
testset = datasets.MNIST('./data', download=True, train=False, transform=transform)

# Defining trainloader and testloader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# Shape of training data
dataiter = iter(trainloader)
images, labels = next(dataiter)

print(images.shape)
print(labels.shape)

# Visualizing the training images
plt.imshow(images[0].numpy().squeeze(), cmap='gray')
plt.show()

# Shape of validation data
dataiter = iter(testloader)
images, labels = next(dataiter)
print(images.shape)
print(labels.shape)

class Net(nn.Module):   
    def __init__(self):
        super(Net, self).__init__()

        self.cnn_layers = nn.Sequential(
            nn.Conv2d(1, 4, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(4),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(4, 8, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.linear_layers = nn.Sequential(
            nn.Linear(8 * 7 * 7, 10)
        )

    def forward(self, x):
        x = self.cnn_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        return x

# Defining the model
model = Net()

# Defining the optimizer
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# Defining the loss function
criterion = nn.CrossEntropyLoss()

# Checking if GPU is available
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()

print(model)
input = torch.randn(1, 1, 28, 28)
out = model(input)
print(out)

summary(model, input_size=(1, 28, 28))

# Training the model
for epoch in range(10):  # Adjust number of epochs
    running_loss = 0
    for images, labels in trainloader:
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()

        # Training pass
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    
    print(f"Epoch {epoch+1} - Training loss: {running_loss / len(trainloader)}")

# Getting predictions on test set and measuring performance
correct_count, all_count = 0, 0
for images, labels in testloader:
    if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
    
    with torch.no_grad():
        output = model(images)
    
    _, preds = torch.max(output, 1)
    correct_count += torch.sum(preds == labels).item()
    all_count += labels.size(0)

print("Number Of Images Tested =", all_count)
print("Model Accuracy =", correct_count / all_count)
# Out:
# 2.4.0
# torch.Size([64, 1, 28, 28])
# torch.Size([64])
# torch.Size([64, 1, 28, 28])
# torch.Size([64])
# Net(
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=392, out_features=10, bias=True)
#   )
# )
# tensor([[ 0.3448, -0.0504, -0.3341,  0.9414, -0.3310,  0.3487, -0.8255, -0.0314,
#          -0.6705, -0.0470]], grad_fn=<AddmmBackward0>)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 4, 28, 28]              40
#        BatchNorm2d-2            [-1, 4, 28, 28]               8
#               ReLU-3            [-1, 4, 28, 28]               0
#          MaxPool2d-4            [-1, 4, 14, 14]               0
#             Conv2d-5            [-1, 8, 14, 14]             296
#        BatchNorm2d-6            [-1, 8, 14, 14]              16
#               ReLU-7            [-1, 8, 14, 14]               0
#          MaxPool2d-8              [-1, 8, 7, 7]               0
#             Linear-9                   [-1, 10]           3,930
# ================================================================
# Total params: 4,290
# Trainable params: 4,290
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.12
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.14
# ----------------------------------------------------------------
# Epoch 1 - Training loss: 0.17553154782636332
# Epoch 2 - Training loss: 0.07404959735163708
# Epoch 3 - Training loss: 0.061447540118144565
# Epoch 4 - Training loss: 0.05336708539395905
# Epoch 5 - Training loss: 0.047882155066347125
# Epoch 6 - Training loss: 0.04515152565898128
# Epoch 7 - Training loss: 0.04202611301212695
# Epoch 8 - Training loss: 0.040388750150424445
# Epoch 9 - Training loss: 0.04030006679496281
# Epoch 10 - Training loss: 0.03810817486972539
# Number Of Images Tested = 10000
# Model Accuracy = 0.9858

# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms
from torch import nn, optim
from torchsummary import summary

print(torch.__version__)

# Transformations to be applied on images
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Defining the training and testing set
trainset = datasets.MNIST('./data', download=True, train=True, transform=transform)
testset = datasets.MNIST('./data', download=True, train=False, transform=transform)

# Defining trainloader and testloader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# Shape of training data
dataiter = iter(trainloader)
images, labels = next(dataiter)

print(images.shape)
print(labels.shape)

# Visualizing the training images
plt.imshow(images[0].numpy().squeeze(), cmap='gray')
plt.show()

# Shape of validation data
dataiter = iter(testloader)
images, labels = next(dataiter)
print(images.shape)
print(labels.shape)

# class Net(nn.Module):   
#     def __init__(self):
#         super(Net, self).__init__()

#         self.cnn_layers = nn.Sequential(
#             nn.Conv2d(1, 4, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(4),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2),
#             nn.Conv2d(4, 8, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(8),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2),
#         )

#         self.linear_layers = nn.Sequential(
#             nn.Linear(8 * 7 * 7, 10)
#         )

#     def forward(self, x):
#         x = self.cnn_layers(x)
#         x = x.view(x.size(0), -1)
#         x = self.linear_layers(x)
#         return x

class NewNet(nn.Module):   
    def __init__(self):
        super(NewNet, self).__init__()

        self.cnn_layers = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.linear_layers = nn.Sequential(
            nn.Linear(32 * 7 * 7, 128),
            nn.ReLU(inplace=True),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.cnn_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        return x

# Define the new model
model = NewNet()


# Defining the model
# model = Net()

# Defining the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# Defining the loss function
criterion = nn.CrossEntropyLoss()

# Checking if GPU is available
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()

print(model)
input = torch.randn(1, 1, 28, 28)
out = model(input)
print(out)

summary(model, input_size=(1, 28, 28))

# Training the model
for epoch in range(15):  # Adjust number of epochs
    running_loss = 0
    for images, labels in trainloader:
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()

        # Training pass
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    
    print(f"Epoch {epoch+1} - Training loss: {running_loss / len(trainloader)}")

# Getting predictions on test set and measuring performance
correct_count, all_count = 0, 0
for images, labels in testloader:
    if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
    
    with torch.no_grad():
        output = model(images)
    
    _, preds = torch.max(output, 1)
    correct_count += torch.sum(preds == labels).item()
    all_count += labels.size(0)

print("Number Of Images Tested =", all_count)
print("Model Accuracy =", correct_count / all_count)
# Out:
# 2.4.0
# torch.Size([64, 1, 28, 28])
# torch.Size([64])
# torch.Size([64, 1, 28, 28])
# torch.Size([64])
# NewNet(
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=1568, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# tensor([[ 0.3557,  0.1266,  0.4221,  0.0669, -0.0211,  0.3339, -0.0744,  0.3588,
#          -0.1781, -0.0449]], grad_fn=<AddmmBackward0>)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             160
#        BatchNorm2d-2           [-1, 16, 28, 28]              32
#               ReLU-3           [-1, 16, 28, 28]               0
#          MaxPool2d-4           [-1, 16, 14, 14]               0
#             Conv2d-5           [-1, 32, 14, 14]           4,640
#        BatchNorm2d-6           [-1, 32, 14, 14]              64
#               ReLU-7           [-1, 32, 14, 14]               0
#          MaxPool2d-8             [-1, 32, 7, 7]               0
#             Linear-9                  [-1, 128]         200,832
#              ReLU-10                  [-1, 128]               0
#            Linear-11                   [-1, 10]           1,290
# ================================================================
# Total params: 207,018
# Trainable params: 207,018
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.47
# Params size (MB): 0.79
# Estimated Total Size (MB): 1.26
# ----------------------------------------------------------------
# Epoch 1 - Training loss: 0.1355009366329243
# Epoch 2 - Training loss: 0.04506726916777645
# Epoch 3 - Training loss: 0.03168216976644307
# Epoch 4 - Training loss: 0.024617426491768554
# Epoch 5 - Training loss: 0.018985466309587286
# Epoch 6 - Training loss: 0.015471955738989124
# Epoch 7 - Training loss: 0.01271840407401414
# Epoch 8 - Training loss: 0.009668101541977413
# Epoch 9 - Training loss: 0.007266277371899415
# Epoch 10 - Training loss: 0.006410456626528456
# Epoch 11 - Training loss: 0.004573834734721288
# Epoch 12 - Training loss: 0.004389768159650084
# Epoch 13 - Training loss: 0.0029059705873142583
# Epoch 14 - Training loss: 0.0027014480454726777
# Epoch 15 - Training loss: 0.0014705788952977833
# Number Of Images Tested = 10000
# Model Accuracy = 0.9915

# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms
from torch import nn, optim
from torchsummary import summary

print(torch.__version__)

# Transformations to be applied on images
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Defining the training and testing set
trainset = datasets.MNIST('./data', download=True, train=True, transform=transform)
testset = datasets.MNIST('./data', download=True, train=False, transform=transform)

# Defining trainloader and testloader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# Shape of training data
dataiter = iter(trainloader)
images, labels = next(dataiter)

print(images.shape)
print(labels.shape)

# Visualizing the training images
plt.imshow(images[0].numpy().squeeze(), cmap='gray')
plt.show()

# Shape of validation data
dataiter = iter(testloader)
images, labels = next(dataiter)
print(images.shape)
print(labels.shape)

# class Net(nn.Module):   
#     def __init__(self):
#         super(Net, self).__init__()

#         self.cnn_layers = nn.Sequential(
#             nn.Conv2d(1, 4, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(4),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2),
#             nn.Conv2d(4, 8, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(8),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2),
#         )

#         self.linear_layers = nn.Sequential(
#             nn.Linear(8 * 7 * 7, 10)
#         )

#     def forward(self, x):
#         x = self.cnn_layers(x)
#         x = x.view(x.size(0), -1)
#         x = self.linear_layers(x)
#         return x

class NewNet(nn.Module):   
    def __init__(self):
        super(NewNet, self).__init__()

        self.cnn_layers = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.linear_layers = nn.Sequential(
            nn.Linear(32 * 7 * 7, 128),
            nn.ReLU(inplace=True),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.cnn_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        return x

# Define the new model
model = NewNet()


# Defining the model
# model = Net()

# Defining the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# Defining the loss function
criterion = nn.CrossEntropyLoss()

# Checking if GPU is available
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()

print(model)
input = torch.randn(1, 1, 28, 28)
out = model(input)
print(out)

summary(model, input_size=(1, 28, 28))

# Training the model
for epoch in range(20):  # Adjust number of epochs
  
    running_loss = 0
    for images, labels in trainloader:
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()

        # Training pass
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    
    print(f"Epoch {epoch+1} - Training loss: {running_loss / len(trainloader)}")

# Getting predictions on test set and measuring performance
correct_count, all_count = 0, 0
for images, labels in testloader:
    if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
    
    with torch.no_grad():
        output = model(images)
    
    _, preds = torch.max(output, 1)
    correct_count += torch.sum(preds == labels).item()
    all_count += labels.size(0)

print("Number Of Images Tested =", all_count)
print("Model Accuracy =", correct_count / all_count)
# Out:
# 2.4.0
# torch.Size([64, 1, 28, 28])
# torch.Size([64])
# torch.Size([64, 1, 28, 28])
# torch.Size([64])
# NewNet(
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=1568, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# tensor([[ 0.0668,  0.1354,  0.1091,  0.4686, -0.2856, -0.2324, -0.1676,  0.1525,
#          -0.1422, -0.1900]], grad_fn=<AddmmBackward0>)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             160
#        BatchNorm2d-2           [-1, 16, 28, 28]              32
#               ReLU-3           [-1, 16, 28, 28]               0
#          MaxPool2d-4           [-1, 16, 14, 14]               0
#             Conv2d-5           [-1, 32, 14, 14]           4,640
#        BatchNorm2d-6           [-1, 32, 14, 14]              64
#               ReLU-7           [-1, 32, 14, 14]               0
#          MaxPool2d-8             [-1, 32, 7, 7]               0
#             Linear-9                  [-1, 128]         200,832
#              ReLU-10                  [-1, 128]               0
#            Linear-11                   [-1, 10]           1,290
# ================================================================
# Total params: 207,018
# Trainable params: 207,018
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.47
# Params size (MB): 0.79
# Estimated Total Size (MB): 1.26
# ----------------------------------------------------------------
# Epoch 1 - Training loss: 0.13934771207569321
# Epoch 2 - Training loss: 0.04623037607926351
# Epoch 3 - Training loss: 0.033969457769960805
# Epoch 4 - Training loss: 0.024070252574407366
# Epoch 5 - Training loss: 0.019252425956348743
# Epoch 6 - Training loss: 0.015012340718579452
# Epoch 7 - Training loss: 0.01240183829137475
# Epoch 8 - Training loss: 0.009099489675845727
# Epoch 9 - Training loss: 0.007167050794831313
# Epoch 10 - Training loss: 0.006430578759130734
# Epoch 11 - Training loss: 0.0052961166136128186
# Epoch 12 - Training loss: 0.0030654229336449287
# Epoch 13 - Training loss: 0.002711727969982234
# Epoch 14 - Training loss: 0.002364216138226739
# Epoch 15 - Training loss: 0.0010752224395656725
# Epoch 16 - Training loss: 0.0006803833819847143
# Epoch 17 - Training loss: 0.0006075246030018943
# Epoch 18 - Training loss: 0.0004516345872916121
# Epoch 19 - Training loss: 0.00038440278133308303
# Epoch 20 - Training loss: 0.00029467255137309204
# Number Of Images Tested = 10000
# Model Accuracy = 0.9926
